# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
plt.xkcd()  # Yes...
plt.plot(sin(linspace(0, 6*pi))/3)
plt.plot(sin(linspace(0, 4*pi))/2)
plt.plot(sin(linspace(0, 2*pi))/1)
plt.title('Whoo Hoo!!!')

# %%
x = sin(linspace(0, 2*pi)) + sin(linspace(0, 4*pi))/2 + sin(linspace(0, 6*pi))/3 
plt.plot(x)
plt.title('mixed wave')

# %%
n = len(x)
y = fft.fft(x)/n

plt.plot(sin(linspace(0, 2*pi))*imag(y[2])/imag(y[2]))
plt.plot(sin(linspace(0, 4*pi))*imag(y[3])/imag(y[2]))
plt.plot(sin(linspace(0, 6*pi))*imag(y[4])/imag(y[2]))
plt.title('wave docomposition')
for i in range(2,6):
    yyy=imag(y[i])/imag(y[2])
    print 'wave number', i-1, ':', yyy
# Out:
# wave number 1 : 1.0
# wave number 2 : 0.590931028225
# wave number 3 : -0.100411274681
# wave number 4 : -0.0631158518122

# %%
back_x = ifft(y)
plot_x = back_x/max(back_x)* max(x)
plt.plot(plot_x)
plt.title('Now we are back')

# %%
plt.plot(plot_x-x)
plt.title('Error is pretty small')
